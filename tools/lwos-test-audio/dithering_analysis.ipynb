# %% [markdown]
# # LightwaveOS Dithering Analysis - Complete Test Suite
#
# Comprehensive analysis of dithering performance using:
# - Host-side simulation (Python reimplementation)
# - Firmware TAP A/B/C captures (real device)
# - Quantitative metrics + visual comparisons
#
# **Test Configurations:**
# - **A**: Bayer ON, Temporal ON (current default)
# - **B**: Bayer OFF, Temporal ON
# - **C**: Bayer ON, Temporal OFF
# - **D**: Bayer OFF, Temporal OFF (no dithering)
